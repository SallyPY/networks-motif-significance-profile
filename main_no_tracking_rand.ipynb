# %%
# %run 'methods_no_tracking_rand.ipynb'

# %% [markdown]
# <h1>Electronic Circuits</h1>

# %%
el_cir_swap_sizes = [10000, 50000, 75000, 100000]
el_cir_num_randomizations = 40

# %%
#s208
el_cir_s208_motif_list = get_profile_list('electronic_circuits/s208_st.txt', el_cir_swap_sizes,
                                         el_cir_num_randomizations)

#s420
el_cir_s420_motif_list = get_profile_list('electronic_circuits/s420_st.txt', el_cir_swap_sizes, 
                                         el_cir_num_randomizations)

#s838
el_cir_s838_motif_list = get_profile_list('electronic_circuits/s838_st.txt', el_cir_swap_sizes, 
                                         el_cir_num_randomizations)

# %% [markdown]
# <h2>Plots mapping number of edge swaps to motif significance profile</h2>

# %% [markdown]
# <h3>s208</h3>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Circuit s208 Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
for i in range(len(el_cir_swap_sizes)):
    plt.plot(el_cir_s208_motif_list[i], label=el_cir_swap_sizes[i])
plt.legend()

# %% [markdown]
# <h3>s420</h3>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Circuit s420 Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
for i in range(len(el_cir_swap_sizes)):
    
    plt.plot(el_cir_s420_motif_list[i], label=el_cir_swap_sizes[i])
plt.legend()

# %% [markdown]
# <h3>s838</h3>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Circuit s838 Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
for i in range(len(el_cir_swap_sizes)):
    plt.plot(el_cir_s838_motif_list[i], label=el_cir_swap_sizes[i])
plt.legend()

# %% [markdown]
# <h2>Plotting circuit motif profiles</h2>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Circuit Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
plt.plot( el_cir_s208_motif_list[2], '.r-', label='s208', markersize=13, linewidth=1)
plt.plot(el_cir_s420_motif_list[2],'.b-', label='s420', markersize=13, linewidth=1)
plt.plot(el_cir_s838_motif_list[2],'.g-', label='s838', markersize=13, linewidth=1)
plt.legend()

print el_cir_s208_motif_list[0][12]
plt.savefig("circuit_graph.pdf")
# Out:
# 0.0

# %% [markdown]
# <h1>Social Networks</h1>

# %%
social_inter_swap_sizes = [1000, 2000, 4000, 10000]
social_inter_num_randomizations = 60

# %%
leader2_inter_motif_list = get_profile_list('social_network/leader2inter_st.txt', social_inter_swap_sizes, 
                                           social_inter_num_randomizations)

prison_inter_motif_list = get_profile_list('social_network/prisoninter_st.txt', social_inter_swap_sizes, 
                                          social_inter_num_randomizations)

# %% [markdown]
# <h2>Plots mapping number of edge swaps to motif significance profile</h2>

# %% [markdown]
# <h3>leader2</h3>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Leader Course Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
for i in range(len(social_inter_swap_sizes)):
    plt.plot(leader2_inter_motif_list[i], label=social_inter_swap_sizes[i])
plt.legend(title="number of edge swaps", bbox_to_anchor=(.4, 1))
plt.savefig("leadership.pdf")

# %% [markdown]
# <h3>prison</h3>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Prison Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
for i in range(len(social_inter_swap_sizes)):
    plt.plot(prison_inter_motif_list[i], label=social_inter_swap_sizes[i])
plt.legend(title="number of edge swaps", bbox_to_anchor=(.4, 1))
plt.savefig("prison.pdf")

# %% [markdown]
# <h2>Plotting motif profiles</h2>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Social Network Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
plt.plot(leader2_inter_motif_list[0], '.r-', label='leader2inter', markersize=13, linewidth=1)
plt.plot(prison_inter_motif_list[0],'.b-', label='prisoninter', markersize=13, linewidth=1)
plt.legend(bbox_to_anchor=(.4, 1))
plt.savefig("prison_leadership.pdf")

# %% [markdown]
# <h1>E-coli</h1>

# %%
e_coli_swap_sizes = [1000, 10000, 50000, 75000, 100000]
e_coli_num_randomizations = 60

# %%
e_coli_motif_list = get_profile_list('e_coli_transcription/1aorinter_st.txt', e_coli_swap_sizes,
                                     e_coli_num_randomizations)

# %% [markdown]
# <h2>Plots mapping number of edge swaps to motif significance profile</h2>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('E-coli Triad Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
for i in range(len(e_coli_swap_sizes)):
    plt.plot(e_coli_motif_list[i], label=e_coli_swap_sizes[i])
plt.legend(title="number of edge swaps")
plt.savefig("e_coli_profiles.pdf")

# %% [markdown]
# <h2>Plotting motif profiles</h2>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('E-coli Transcription Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
plt.plot(e_coli_motif_list[0], '.r-', label='e-coli', markersize=13, linewidth=1)
plt.legend()

# %% [markdown]
# <h1>Yeast Transcription</h1>

# %%
yeast_trans_swap_sizes = [10000, 50000, 75000, 100000]
yeast_trans_num_randomizations = 30

# %%
yeast_trans_motif_list = get_profile_list('yeast_transcription/yeastinter_st.txt', yeast_trans_swap_sizes,
                                    yeast_trans_num_randomizations)

# %% [markdown]
# <h2>Plots mapping number of edge swaps to motif significance profile</h2>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Yeast Trascription Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
for i in range(len(yeast_trans_swap_sizes)):
    plt.plot(yeast_trans_motif_list[i], label=yeast_trans_swap_sizes[i])
plt.legend()

# %% [markdown]
# <h2>Plotting motif profiles</h2>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Yeast Transcription Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
plt.plot(yeast_trans_motif_list[0], '.r-', label='yeast_trans', markersize=13, linewidth=1)
plt.legend()

# %% [markdown]
# <h2>Transcription Motif profiles</h2>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Transcription Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
plt.plot(yeast_trans_motif_list[0], '.r-', label='yeast_trans', markersize=13, linewidth=1)
plt.plot(e_coli_motif_list[0],'.b-', label='e_coli_trans', markersize=13, linewidth=1)
plt.legend()

plt.savefig("transcription_graph.pdf")

# %% [markdown]
# <h1>Word Adjacencies</h1>

# %%
text_swap_sizes = [10000, 50000]
text_num_randomizations = 10

# %%
darwin_motif_list = get_profile_list('word_adjacency/darwinbookinter_st.txt', text_swap_sizes,
                                    text_num_randomizations)

# %%
french_motif_list = get_profile_list('word_adjacency/frenchbookinter_st.txt', dict_swap_sizes,
                                    dict_num_randomizations)
japanese_motif_list = get_profile_list('word_adjacency/japanesebookinter_st.txt', dict_swap_sizes,
                                    dict_num_randomizations)
spanish_motif_list = get_profile_list('word_adjacency/spanishbookinter_st.txt', dict_swap_sizes,
                                    dict_num_randomizations)

# %% [markdown]
# <h2>Plots mapping number of edge swaps to motif significance profile</h2>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Word Adjacency Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
for i in range(len(text_swap_sizes)):
    plt.plot(carwin_motif_list[i], label=text_swap_sizes[i])
plt.legend()

# %% [markdown]
# <h2>Plotting motif profiles</h2>

# %%
plt.xlabel('Motif')
plt.ylabel('Z-score')
plt.title('Word Adjacency Motif Signicance Profile')
plt.xticks( np.arange(13), [i for i in range(1, 14)] )
plt.plot(darwin_motif_list[0], '.b-', label='darwin', markersize=13, linewidth=2)
# plt.plot(french_motif_list[0], '.r-', label='french', markersize=13, linewidth=2)
# plt.plot(japanese_motif_list[0], '.g-', label='japanese', markersize=13, linewidth=2)
# plt.plot(spanish_motif_list[0], '.m-', label='spanish', markersize=13, linewidth=2)

plt.legend()
